# %%
import tensorflow as tf
import json
import numpy as np
from tensorflow import keras as tfk
import os
from pymongo import MongoClient
import pandas as pd

# %%
convos = ['conversation1', 'conversation2', 'conversation3']
vocons = []
for y in convos:
#     with open(f'conversations_kaggle/{y}.txt', 'r') as unoconvo:
#         vocons.append(unoconvo.read())
    vocons.append(pd.read_csv('conversations_kaggle/'+str(y)+'.txt', delimiter='\n\n', header=None))
# Out:
# C:\Users\Loaf\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
for y, x in vocons:
    x.to_csv(convos[y]+'.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-af1c9ae248be> in <module>
#       1 for x in vocons:
# ----> 2     x.to_csv(convos[vocons.index(x)]+'.csv', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    2094             # Another DataFrame
#    2095             if not self._indexed_same(other):
# -> 2096                 raise ValueError('Can only compare identically-labeled '
#    2097                                  'DataFrame objects')
#    2098             return dispatch_to_series(self, other, func, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects
